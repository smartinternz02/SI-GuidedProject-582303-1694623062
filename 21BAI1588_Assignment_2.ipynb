# %% [markdown]
# ##21BAI1588 G REVANTH

# %%
Assignment 8 th september
1.Take car crashes dataset from seaborn library
2.load the dataset
3.Perfrom Data Visualization
4.Inference is must for each and every graph
5.Submit it by wednesday in html format

#21BAI1588 G REVANTH

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#21BAI1588 G REVANTH

# %%
print(sns.get_dataset_names())

#21BAI1588 G REVANTH
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
df=sns.load_dataset('car_crashes')

#21BAI1588 G REVANTH

# %%
df.head()

#21BAI1588 G REVANTH
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
df.tail()

#21BAI1588 G REVANTH
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 46   12.7     2.413    3.429          11.049       11.176       768.95
# 47   10.6     4.452    3.498           8.692        9.116       890.03
# 48   23.8     8.092    6.664          23.086       20.706       992.61
# 49   13.8     4.968    4.554           5.382       11.592       670.31
# 50   17.4     7.308    5.568          14.094       15.660       791.14
#
#     ins_losses abbrev
# 46      153.72     VA
# 47      111.62     WA
# 48      152.56     WV
# 49      106.62     WI
# 50      122.04     WY

# %%
df.info()

#21BAI1588 G REVANTH
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   total           51 non-null     float64
#  1   speeding        51 non-null     float64
#  2   alcohol         51 non-null     float64
#  3   not_distracted  51 non-null     float64
#  4   no_previous     51 non-null     float64
#  5   ins_premium     51 non-null     float64
#  6   ins_losses      51 non-null     float64
#  7   abbrev          51 non-null     object
# dtypes: float64(7), object(1)
# memory usage: 3.3+ KB

# %%
sns.scatterplot(x="speeding",y="total",data=df)

#21BAI1588 G REVANTH
# Out:
# <Axes: xlabel='speeding', ylabel='total'>

# %% [markdown]
# Inference:from the plot we can say that as speeding increases total accidents are also increasing

# %%
sns.scatterplot(x="alcohol",y="total",data=df)

#21BAI1588 G REVANTH
# Out:
# <Axes: xlabel='alcohol', ylabel='total'>

# %% [markdown]
# Inference:from the plot we can say that as alcohol driving increases total accidents are also increasing

# %%
sns.scatterplot(x="not_distracted",y="total",data=df)

#21BAI1588 G REVANTH
# Out:
# <Axes: xlabel='not_distracted', ylabel='total'>

# %% [markdown]
# Inference:from the plot we can say that even when driver is not distracted increases total accidents are increasing

# %%
sns.scatterplot(x="no_previous",y="total",data=df)

#21BAI1588 G REVANTH
# Out:
# <Axes: xlabel='no_previous', ylabel='total'>

# %% [markdown]
# Inference:from the plot we can say that even when driver had no previous accidents increases total accidents are increasing

# %%
sns.scatterplot(x="speeding",y="total",hue="alcohol",data=df)

#21BAI1588 G REVANTH
# Out:
# <Axes: xlabel='speeding', ylabel='total'>

# %%
sns.scatterplot(x="alcohol",y="total",hue="no_previous",data=df)

#21BAI1588 G REVANTH
# Out:
# <Axes: xlabel='alcohol', ylabel='total'>

# %%
sns.lineplot(data=df)

#21BAI1588 G REVANTH
# Out:
# <Axes: >

# %%
sns.lineplot(x="speeding",y="total",data=df)

#21BAI1588 G REVANTH
# Out:
# <Axes: xlabel='speeding', ylabel='total'>

# %%
sns.lineplot(x = "alcohol", y = "total", data = df)

#21BAI1588 G REVANTH
# Out:
# <Axes: xlabel='alcohol', ylabel='total'>

# %%
sns.lineplot(x = "no_previous", y = "total", data = df)

#21BAI1588 G REVANTH
# Out:
# <Axes: xlabel='no_previous', ylabel='total'>

# %%
sns.lineplot(x = "ins_premium", y = "total", data = df)

#21BAI1588 G REVANTH
# Out:
# <Axes: xlabel='ins_premium', ylabel='total'>

# %%
sns.lineplot(x = "ins_losses", y = "total", data = df)

#21BAI1588 G REVANTH
# Out:
# <Axes: xlabel='ins_losses', ylabel='total'>

# %%
sns.distplot(df["speeding"]) # Univariate Analysis

#21BAI1588 G REVANTH
# Out:
# <ipython-input-67-573c760d22f1>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["speeding"]) # Univariate Analysis
# <Axes: xlabel='speeding', ylabel='Density'>

# %%
sns.distplot(df["alcohol"])

#21BAI1588 G REVANTH
# Out:
# <ipython-input-68-a66f3f503cba>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["alcohol"])
# <Axes: xlabel='alcohol', ylabel='Density'>

# %%
sns.distplot(df["not_distracted"])

#21BAI1588 G REVANTH
# Out:
# <ipython-input-69-9bffc5990d2c>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["not_distracted"])
# <Axes: xlabel='not_distracted', ylabel='Density'>

# %%
sns.distplot(df["no_previous"])

#21BAI1588 G REVANTH
# Out:
# <ipython-input-70-20b20c279c45>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["no_previous"])
# <Axes: xlabel='no_previous', ylabel='Density'>

# %%
sns.relplot(x="total",y="speeding",data=df,hue="alcohol") #relational plot

#21BAI1588 G REVANTH

# %%
sns.relplot(x="total",y="speeding",data=df,hue="abbrev")

#21BAI1588 G REVANTH

# %%
plt.subplots(figsize=(16, 10))
sns.barplot(data=df,x="abbrev",y="total")

#21BAI1588 G REVANTH
# Out:
# <Axes: xlabel='abbrev', ylabel='total'>

# %%
plt.subplots(figsize=(16, 10))
sns.barplot(data=df,x="speeding",y="abbrev")

#21BAI1588 G REVANTH
# Out:
# <Axes: xlabel='speeding', ylabel='abbrev'>

# %%
sns.jointplot(x = 'total', y = 'alcohol', data = df)

#21BAI1588 G REVANTH

# %%
sns.jointplot(x = 'total', y = 'speeding', data = df)

#21BAI1588 G REVANTH

# %%
sns.jointplot(x = 'total', y = 'not_distracted', data = df)

#21BAI1588 G REVANTH

# %%
sns.jointplot(x = 'total', y = 'no_previous', data = df)

#21BAI1588 G REVANTH

# %%
sns.jointplot(x = 'ins_losses', y = 'ins_premium', data = df)

#21BAI1588 G REVANTH

# %%
sns.jointplot(x = 'ins_losses', y = 'ins_losses', data = df)

#21BAI1588 G REVANTH

# %%
corr=df.corr()
corr

#21BAI1588 G REVANTH
# Out:
# <ipython-input-81-93cf8f47a3b6>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=df.corr()
#                    total  speeding   alcohol  not_distracted  no_previous  \
# total           1.000000  0.611548  0.852613        0.827560     0.956179
# speeding        0.611548  1.000000  0.669719        0.588010     0.571976
# alcohol         0.852613  0.669719  1.000000        0.732816     0.783520
# not_distracted  0.827560  0.588010  0.732816        1.000000     0.747307
# no_previous     0.956179  0.571976  0.783520        0.747307     1.000000
# ins_premium    -0.199702 -0.077675 -0.170612       -0.174856    -0.156895
# ins_losses     -0.036011 -0.065928 -0.112547       -0.075970    -0.006359
#
#                 ins_premium  ins_losses
# total             -0.199702   -0.036011
# ...

# %%
# >0.5 is highly correleated
# <0.5 is less correlated

#21BAI1588 G REVANTH

# %%
sns.heatmap(corr,annot=True)


#21BAI1588 G REVANTH
# Out:
# <Axes: >

# %%
sns.heatmap(corr,annot=True,cmap="YlGnBu")

#21BAI1588 G REVANTH
# Out:
# <Axes: >

# %%
sns.pairplot(df)

#21BAI1588 G REVANTH
